# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(RColorBrewer)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Warning message:
# “package ‘tidymodels’ was built under R version 4.0.2”
# ── Attaching packages ────────────────────────────────────── tidymodels 0.1.1 ──
#
# ✔ broom     0.7.0      ✔ recipes   0.1.13
# ✔ dials     0.0.9      ✔ rsample   0.0.7
# ✔ infer     0.5.4      ✔ tune      0.1.1
# ✔ modeldata 0.0.2      ✔ workflows 0.2.0
# ✔ parsnip   0.1.3      ✔ yardstick 0.0.7
#
# Warning message:
# “package ‘broom’ was built under R version 4.0.2”
# Warning message:
# “package ‘dials’ was built under R version 4.0.2”
# Warning message:
# “package ‘infer’ was built under R version 4.0.3”
# Warning message:
# “package ‘modeldata’ was built under R version 4.0.1”
# Warning message:
# “package ‘parsnip’ was built under R version 4.0.2”
# Warning message:
# “package ‘recipes’ was built under R version 4.0.1”
# Warning message:
# “package ‘tune’ was built under R version 4.0.2”
# Warning message:
# “package ‘workflows’ was built under R version 4.0.2”
# Warning message:
# “package ‘yardstick’ was built under R version 4.0.2”
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()

# %%
data <- read_csv("atp2017-2019.csv")
data
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   tourney_id = col_character(),
#   tourney_name = col_character(),
#   surface = col_character(),
#   tourney_level = col_character(),
#   winner_seed = col_character(),
#   winner_entry = col_character(),
#   winner_name = col_character(),
#   winner_hand = col_character(),
#   winner_ioc = col_character(),
#   loser_seed = col_character(),
#   loser_entry = col_character(),
#   loser_name = col_character(),
#   loser_hand = col_character(),
#   loser_ioc = col_character(),
#   score = col_character(),
#   round = col_character()
# )
#
# See spec(...) for full column specifications.
#      X1   tourney_id                     tourney_name               surface
# 1     0   2019-M020                      Brisbane                   Hard
# 2     1   2019-M020                      Brisbane                   Hard
# 3     2   2019-M020                      Brisbane                   Hard
# 4     3   2019-M020                      Brisbane                   Hard
# 5     4   2019-M020                      Brisbane                   Hard
# 6     5   2019-M020                      Brisbane                   Hard
# 7     6   2019-M020                      Brisbane                   Hard
# 8     7   2019-M020                      Brisbane                   Hard
# 9     8   2019-M020                      Brisbane                   Hard
# 10    9   2019-M020                      Brisbane                   Hard
# 11   10   2019-M020                      Brisbane                   Hard
# 12   11   2019-M020                      Brisbane                   Hard
# 13   12   2019-M020                      Brisbane                   Hard
# 14   13   2019-M020                      Brisbane                   Hard
# 15   14   2019-M020                      Brisbane                   Hard
# 16   15   2019-M020                      Brisbane                   Hard
# 17   16   2019-M020                      Brisbane                   Hard
# 18   17   2019-M020                      Brisbane                   Hard
# 19   18   2019-M020                      Brisbane                   Hard
# 20   19   2019-M020                      Brisbane                   Hard
# 21   20   2019-M020                      Brisbane                   Hard
# 22   21   2019-M020                      Brisbane                   Hard
# 23   22   2019-M020                      Brisbane                   Hard
# 24   23   2019-M020                      Brisbane                   Hard
# 25   24   2019-M020                      Brisbane                   Hard
# 26   25   2019-M020                      Brisbane                   Hard
# 27   26   2019-M020                      Brisbane                   Hard
# 28   28   2019-0451                      Doha                       Hard
# 29   30   2019-0451                      Doha                       Hard
# 30   32   2019-0451                      Doha                       Hard
# ⋮    ⋮    ⋮                              ⋮                          ⋮
# 6837 2846 2017-0352                      Paris Masters              Hard
# 6838 2847 2017-0352                      Paris Masters              Hard
# 6839 2848 2017-0352                      Paris Masters              Hard
# 6840 2849 2017-0352                      Paris Masters              Hard
# 6841 2850 2017-0352                      Paris Masters              Hard
# 6842 2851 2017-0352                      Paris Masters              Hard
# 6843 2853 2017-0352                      Paris Masters              Hard
# 6844 2854 2017-0352                      Paris Masters              Hard
# 6845 2856 2017-0352                      Paris Masters              Hard
# 6846 2857 2017-0352                      Paris Masters              Hard
# 6847 2858 2017-0352                      Paris Masters              Hard
# 6848 2859 2017-0352                      Paris Masters              Hard
# 6849 2862 2017-0352                      Paris Masters              Hard
# 6850 2863 2017-0352                      Paris Masters              Hard
# 6851 2865 2017-0352                      Paris Masters              Hard
# 6852 2867 2017-0605                      Tour Finals                Hard
# 6853 2870 2017-0605                      Tour Finals                Hard
# 6854 2872 2017-0605                      Tour Finals                Hard
# 6855 2873 2017-0605                      Tour Finals                Hard
# 6856 2874 2017-0605                      Tour Finals                Hard
# 6857 2875 2017-0605                      Tour Finals                Hard
# 6858 2876 2017-0605                      Tour Finals                Hard
# 6859 2877 2017-0605                      Tour Finals                Hard
# 6860 2878 2017-0605                      Tour Finals                Hard
# 6861 2879 2017-0605                      Tour Finals                Hard
# 6862 2881 2017-0605                      Tour Finals                Hard
# 6863 2882 2017-M-DC-2017-WG-M-BEL-FRA-01 Davis Cup WG F: BEL vs FRA Hard
# 6864 2883 2017-M-DC-2017-WG-M-BEL-FRA-01 Davis Cup WG F: BEL vs FRA Hard
# 6865 2884 2017-M-DC-2017-WG-M-BEL-FRA-01 Davis Cup WG F: BEL vs FRA Hard
# 6866 2885 2017-M-DC-2017-WG-M-BEL-FRA-01 Davis Cup WG F: BEL vs FRA Hard
#      draw_size tourney_level tourney_date match_num winner_id winner_seed ⋯
# 1    32        A             20181231     300       105453    2           ⋯
# 2    32        A             20181231     299       106421    4           ⋯
# 3    32        A             20181231     298       105453    2           ⋯
# 4    32        A             20181231     297       104542    NA          ⋯
# 5    32        A             20181231     296       106421    4           ⋯
# 6    32        A             20181231     295       104871    NA          ⋯
# 7    32        A             20181231     294       105453    2           ⋯
# 8    32        A             20181231     293       104542    NA          ⋯
# 9    32        A             20181231     292       200282    7           ⋯
# 10   32        A             20181231     291       106421    4           ⋯
# 11   32        A             20181231     290       105683    5           ⋯
# 12   32        A             20181231     289       104871    NA          ⋯
# 13   32        A             20181231     288       106034    NA          ⋯
# 14   32        A             20181231     287       105777    6           ⋯
# 15   32        A             20181231     286       105453    2           ⋯
# 16   32        A             20181231     284       104542    NA          ⋯
# 17   32        A             20181231     283       111442    NA          ⋯
# 18   32        A             20181231     282       200282    7           ⋯
# 19   32        A             20181231     280       104918    NA          ⋯
# 20   32        A             20181231     279       200175    NA          ⋯
# 21   32        A             20181231     278       105683    5           ⋯
# 22   32        A             20181231     277       106401    8           ⋯
# 23   32        A             20181231     276       104871    NA          ⋯
# 24   32        A             20181231     275       106034    NA          ⋯
# 25   32        A             20181231     273       105777    6           ⋯
# 26   32        A             20181231     272       105357    NA          ⋯
# 27   32        A             20181231     271       106045    NA          ⋯
# 28   32        A             20181231     299       105138    7           ⋯
# 29   32        A             20181231     297       104925    1           ⋯
# 30   32        A             20181231     295       106065    4           ⋯
# ⋮    ⋮         ⋮             ⋮            ⋮         ⋮         ⋮           ⋱
# 6837 64        M             20171030     280       105223    13.0        ⋯
# 6838 64        M             20171030     281       104898    NA          ⋯
# 6839 64        M             20171030     282       103917    NA          ⋯
# 6840 64        M             20171030     283       105936    NA          ⋯
# 6841 64        M             20171030     284       104655    NA          ⋯
# 6842 64        M             20171030     285       104745    1.0         ⋯
# 6843 64        M             20171030     287       104269    NA          ⋯
# 6844 64        M             20171030     288       105227    3.0         ⋯
# 6845 64        M             20171030     290       104545    9.0         ⋯
# 6846 64        M             20171030     291       105223    13.0        ⋯
# 6847 64        M             20171030     292       105936    NA          ⋯
# 6848 64        M             20171030     293       104745    1.0         ⋯
# 6849 64        M             20171030     296       104545    9.0         ⋯
# 6850 64        M             20171030     297       105936    NA          ⋯
# 6851 64        M             20171030     299       105936    NA          ⋯
# 6852  8        F             20171113     286       105676    7.0         ⋯
# 6853  8        F             20171113     289       100644    3.0         ⋯
# 6854  8        F             20171113     291       103819    2.0         ⋯
# 6855  8        F             20171113     292       103819    2.0         ⋯
# 6856  8        F             20171113     293       105777    6.0         ⋯
# 6857  8        F             20171113     294       105676    7.0         ⋯
# 6858  8        F             20171113     295       105777    6.0         ⋯
# 6859  8        F             20171113     296       105777    6.0         ⋯
# 6860  8        F             20171113     297       106233    4.0         ⋯
# 6861  8        F             20171113     298       105676    7.0         ⋯
# 6862  8        F             20171113     300       105777    6.0         ⋯
# 6863  4        D             20171124       1       105676    NA          ⋯
# 6864  4        D             20171124       2       104542    NA          ⋯
# 6865  4        D             20171124       4       105676    NA          ⋯
# 6866  4        D             20171124       5       106298    NA          ⋯
#      l_1stIn l_1stWon l_2ndWon l_SvGms l_bpSaved l_bpFaced winner_rank
# 1    54      34       20       14      10        15          9
# 2    52      36        7       10      10        13         16
# 3    27      15        6        8       1         5          9
# 4    60      38        9       11       4         6        239
# 5    56      46       19       15       2         4         16
# 6    54      40       18       15       6         9         40
# 7    53      37       13       12       6         9          9
# 8    51      34       11       11       6        11        239
# 9    39      30        3        9       3         6         31
# 10   39      27        7       10       2         6         16
# 11   44      28       18       10       2         3         18
# 12   59      48       10       14       2         5         40
# 13   50      35       14       11       1         2        185
# 14   37      18       10        9       3         7         19
# 15   36      26        8       10       4         7          9
# 16   46      34       10       11       1         3        239
# 17   33      17       12        7       8        13         72
# 18   31      18        4        8       4         9         31
# 19   34      23        9        9       1         4        240
# 20   29      18        7        8       4         8        131
# 21   30      16        2        7       4         8         18
# 22   77      60       24       18       5         5         35
# 23   41      32       22       14       4         6         40
# 24   45      35       14       11       0         1        185
# 25   33      21        7        9       0         3         19
# 26   63      44       20       15      13        18         38
# 27   72      57       27       17       9        10         63
# 28   72      48       27       16       6         8         24
# 29   54      39       12       14       3         7          1
# 30   46      33        6       10       5         7         20
# ⋮    ⋮       ⋮        ⋮        ⋮       ⋮         ⋮         ⋮
# 6837 32      22        3        8       4         8         17
# 6838 55      36       13       13       7        11         43
# 6839 29      19       10        8       6        10        111
# 6840 37      27       11       10       2         5         77
# 6841 60      44       21       16       5         9         36
# 6842 45      25       10       10       4         8          1
# 6843 33      19       22       10       6         9         39
# 6844 34      23       13       10       4         8          5
# 6845 72      64       18       18       1         2         14
# 6846 35      28       12       11       0         3         17
# 6847 38      24       17       12       1         6         77
# 6848 47      33       24       14       6        10          1
# 6849 66      55       12       16       0         2         14
# 6850 NA      NA       NA       NA      NA        NA         77
# 6851 74      63       12       17       0         1         77
# 6852 NA      NA       NA       NA      NA        NA          8
# 6853 50      37       17       15       1         4          3
# 6854 50      35       27       14       6         9          2
# 6855 67      49       17       16       4         8          2
# 6856 32      20        5        7       6        11          6
# 6857 21      14       10        9       2         7          8
# 6858 44      35       25       16       5         8          6
# 6859 34      16        4        7       5        10          6
# 6860 67      41       18       14       9        13          4
# 6861 47      35       17       13       1         3          8
# 6862 54      42       22       15      11        15          6
# 6863 53      33       21       14       6        11          7
# 6864 54      30       12       12       5        11         15
# 6865 54      44       13       14       7        10          7
# 6866 53      29       11       11       4        11         18
#      winner_rank_points loser_rank loser_rank_points
# 1    3590                16        1977
# 2    1977               239         200
# 3    3590                40        1050
# 4     200                31        1298
# 5    1977                18        1855
# 6    1050               185         275
# 7    3590                19        1835
# 8     200                77         691
# 9    1298                72         715
# 10   1977               240         200
# 11   1855               131         433
# 12   1050                35        1125
# 13    275                14        2150
# 14   1835                38        1083
# 15   3590                63         810
# 16    200               146         367
# 17    715               154         352
# 18   1298               147         367
# 19    200               234         206
# 20    433                56         895
# 21   1855                67         780
# 22   1125                62         810
# 23   1050                57         875
# 24    275               102         572
# 25   1835                75         701
# 26   1083                61         814
# 27    810                49         974
# 28   1605                 1        9045
# 29   9045                21        1795
# 30   1819                48         985
# ⋮    ⋮                  ⋮          ⋮
# 6837  2435               58          825
# 6838  1075                4         4400
# 6839   516               11         2650
# 6840   681               13         2525
# 6841  1280               24         1880
# 6842 10465               55          889
# 6843  1160                6         3935
# 6844  4185               23         1935
# 6845  2505                8         3650
# 6846  2435               43         1075
# 6847   681              111          516
# 6848 10465               36         1280
# 6849  2505               17         2435
# 6850   681                1        10465
# 6851   681               14         2505
# 6852  2975                1        10645
# 6853  4410                5         3805
# 6854  9005                5         3805
# 6855  9005                3         4410
# 6856  3650                8         2975
# 6857  2975                4         3815
# 6858  3650                4         3815
# 6859  3650               10         2615
# 6860  3815               10         2615
# 6861  2975                2         9005
# 6862  3650                8         2975
# 6863  3775               18         2235
# 6864  2320               76          667
# 6865  3775               15         2320
# 6866  2235               76          667

# %%
data <- data%>%
	select(winner_name, winner_hand, winner_ht, winner_ioc, winner_age, winner_rank)%>%
#the columns relevant to our analysis are selected using this select() function
	filter(!is.na(winner_ht), !is.na(winner_rank), !is.na(winner_age), !is.na(winner_ioc),
		!is.na(winner_hand))%>%
#the !is.na() argument in the filter() function eliminates NA values in the relevant
#columns
	mutate(winner_hand = as_factor(winner_hand), winner_ioc = as_factor(winner_ioc),
		winner_rank = as.double(winner_rank))%>%
#this mutate() function converts the relevant columns to appropriate data types
	distinct()
#the distinct() function eliminates identical rows, keeping only unique rows, and was
#used due to the fact that some tennis players return every year, causing repeats
data
# Out:
#      winner_name                 winner_hand winner_ht winner_ioc winner_age
# 1    Kei Nishikori               R           178       JPN        29.00479
# 2    Jo Wilfried Tsonga          R           188       FRA        33.70568
# 3    Jeremy Chardy               R           188       FRA        31.88227
# 4    Milos Raonic                R           196       CAN        28.01095
# 5    Grigor Dimitrov             R           188       BUL        27.62765
# 6    Andy Murray                 R           190       GBR        31.63039
# 7    Nick Kyrgios                R           193       AUS        23.67967
# 8    John Millman                R           183       AUS        29.54689
# 9    Denis Kudla                 R           180       USA        26.37098
# 10   Roberto Bautista Agut       R           183       ESP        30.71321
# 11   Novak Djokovic              R           188       SRB        31.61123
# 12   Nikoloz Basilashvili        R           185       RUS        26.85284
# 13   Dusan Lajovic               R           180       SRB        28.50376
# 14   Pierre Hugues Herbert       R           188       FRA        27.78919
# 15   Ricardas Berankis           R           175       LTU        28.52841
# 16   Guido Pella                 L           185       ARG        28.62423
# 17   Fernando Verdasco           L           188       ESP        35.12663
# 18   Kevin Anderson              R           203       RSA        32.62149
# 19   Ivo Karlovic                R           208       CRO        39.83847
# 20   Gilles Simon                R           183       FRA        34.00958
# 21   Benoit Paire                R           196       FRA        29.64819
# 22   Malek Jaziri                R           185       TUN        34.94593
# 23   Ernests Gulbis              R           190       LAT        30.33539
# 24   Simone Bolelli              R           183       ITA        33.22930
# 25   Evgeny Donskoy              R           185       RUS        28.64613
# 26   Philipp Kohlschreiber       R           178       GER        35.22793
# 27   Leonardo Mayer              R           188       ARG        31.64956
# 28   Fabio Fognini               R           178       ITA        31.62491
# 29   Joao Sousa                  R           185       POR        29.77413
# 30   Peter Gojowczyk             R           185       GER        29.48118
# ⋮    ⋮                           ⋮           ⋮         ⋮          ⋮
# 2449 Gilles Simon                R           183       FRA        32.82136
# 2450 Alexander Zverev            R           198       GER        20.50924
# 2451 Feliciano Lopez             L           188       ESP        36.10951
# 2452 Fernando Verdasco           L           188       ESP        33.95756
# 2453 Peter Gojowczyk             R           185       GER        28.29295
# 2454 Jeremy Chardy               R           188       FRA        30.71321
# 2455 Richard Gasquet             R           185       FRA        31.36756
# 2456 Diego Sebastian Schwartzman R           170       ARG        25.20465
# 2457 Joao Sousa                  R           185       POR        28.58590
# 2458 Robin Haase                 R           190       NED        30.56810
# 2459 Nicolas Mahut               R           190       FRA        35.77276
# 2460 Filip Krajinovic            R           185       SRB        25.67283
# 2461 Pablo Cuevas                R           180       URU        31.82752
# 2462 Lucas Pouille               R           185       FRA        23.68241
# 2463 Dominic Thiem               R           185       AUT        24.15606
# 2464 Marin Cilic                 R           198       CRO        29.08693
# 2465 Roberto Bautista Agut       R           183       ESP        29.54415
# 2466 David Goffin                R           163       BEL        26.89665
# 2467 Grigor Dimitrov             R           188       BUL        26.45859
# 2468 John Isner                  R           206       USA        32.51198
# 2469 Juan Martin Del Potro       R           198       ARG        29.10062
# 2470 Rafael Nadal                L           185       ESP        31.40862
# 2471 David Goffin                R           163       BEL        26.93498
# 2472 Alexander Zverev            R           198       GER        20.56674
# 2473 Roger Federer               R           185       SUI        36.26557
# 2474 Grigor Dimitrov             R           188       BUL        26.49692
# 2475 Dominic Thiem               R           185       AUT        24.19439
# 2476 David Goffin                R           163       BEL        26.95414
# 2477 Jo Wilfried Tsonga          R           188       FRA        32.59411
# 2478 Lucas Pouille               R           185       FRA        23.73990
#      winner_rank
# 1      9
# 2    239
# 3     40
# 4     18
# 5     19
# 6    240
# 7     35
# 8     38
# 9     63
# 10    24
# 11     1
# 12    21
# 13    48
# 14    55
# 15   116
# 16    58
# 17    28
# 18     6
# 19   100
# 20    30
# 21    52
# 22    45
# 23    95
# 24   141
# 25    97
# 26    34
# 27    54
# 28    13
# 29    44
# 30    60
# ⋮    ⋮
# 2449  74
# 2450   5
# 2451  33
# 2452  39
# 2453  62
# 2454  88
# 2455  30
# 2456  25
# 2457  58
# 2458  43
# 2459 111
# 2460  77
# 2461  36
# 2462  18
# 2463   6
# 2464   5
# 2465  23
# 2466  10
# 2467   8
# 2468  14
# 2469  17
# 2470   1
# 2471   8
# 2472   3
# 2473   2
# 2474   6
# 2475   4
# 2476   7
# 2477  15
# 2478  18

# %%
data <- data%>%
    group_by(winner_name, winner_hand, winner_ht, winner_ioc)%>%
    summarize(number_of_wins = n(), winner_avg_age = mean(winner_age), winner_avg_rank = mean(winner_rank))%>%
    select(winner_name, winner_hand, winner_ht, winner_ioc, winner_avg_age, winner_avg_rank)
data <- mutate(data, winner_avg_age = round(winner_avg_age, 2))
data <- mutate(data, winner_avg_rank = round(winner_avg_rank, 2))
head(data, 6)
# Out:
# `summarise()` regrouping output by 'winner_name', 'winner_hand', 'winner_ht' (override with `.groups` argument)
#   winner_name          winner_hand winner_ht winner_ioc winner_avg_age
# 1 Adrian Mannarino     L           183       FRA        30.00
# 2 Albert Ramos         L           188       ESP        30.27
# 3 Alessandro Giannessi L           183       ITA        27.39
# 4 Alexander Zverev     R           198       GER        21.11
# 5 Aljaz Bedene         R           181       SLO        28.80
# 6 Andreas Seppi        R           190       ITA        34.23
#   winner_avg_rank
# 1  42.29
# 2  46.52
# 3 137.00
# 4   7.51
# 5  66.42
# 6  65.03

# %%
set.seed(9999) 

data_split <- initial_split(data, prop = 0.75, strata = winner_avg_rank)
data_train <- training(data_split)
data_test <- testing(data_split)

data_train
# Out:
#    winner_name                 winner_hand winner_ht winner_ioc winner_avg_age
# 1  Adrian Mannarino            L           183       FRA        30.00
# 2  Albert Ramos                L           188       ESP        30.27
# 3  Alessandro Giannessi        L           183       ITA        27.39
# 4  Aljaz Bedene                R           181       SLO        28.80
# 5  Andrej Martin               R           180       SVK        28.72
# 6  Andy Murray                 R           190       GBR        31.05
# 7  Attila Balazs               R           180       HUN        30.28
# 8  Bernard Tomic               R           193       AUS        25.60
# 9  Blaz Kavcic                 R           188       SLO        31.12
# 10 Bradley Klahn               L           190       USA        28.50
# 11 Brydan Klein                R           183       AUS        27.03
# 12 Damir Dzumhur               R           172       BIH        25.86
# 13 Daniel Evans                R           175       GBR        28.33
# 14 Denis Istomin               R           188       UZB        31.41
# 15 Denis Kudla                 R           180       USA        26.25
# 16 Diego Sebastian Schwartzman R           170       ARG        25.81
# 17 Dominic Thiem               R           185       AUT        24.70
# 18 Donald Young                L           183       USA        27.95
# 19 Dusan Lajovic               R           180       SRB        27.93
# 20 Dustin Brown                R           196       GER        32.65
# 21 Ernests Gulbis              R           190       LAT        29.86
# 22 Evgeny Donskoy              R           185       RUS        27.98
# 23 Fernando Verdasco           L           188       ESP        34.60
# 24 Filip Krajinovic            R           185       SRB        26.75
# 25 Gael Monfils                R           193       FRA        31.88
# 26 Gastao Elias                R           178       POR        26.57
# 27 Go Soeda                    R           178       JPN        34.04
# 28 Guido Pella                 L           185       ARG        28.21
# 29 Guillermo Garcia Lopez      R           188       ESP        34.81
# 30 Illya Marchenko             R           185       UKR        29.43
# ⋮  ⋮                           ⋮           ⋮         ⋮          ⋮
# 55 Milos Raonic                R           196       CAN        27.44
# 56 Mischa Zverev               L           190       GER        30.30
# 57 Mohamed Safwat              R           183       EGY        27.91
# 58 Nick Kyrgios                R           193       AUS        23.02
# 59 Nikoloz Basilashvili        R           185       RUS        26.40
# 60 Novak Djokovic              R           188       SRB        31.14
# 61 Pablo Andujar               R           180       ESP        33.18
# 62 Pablo Carreno Busta         R           188       ESP        26.83
# 63 Pablo Cuevas                R           180       URU        32.45
# 64 Peter Gojowczyk             R           185       GER        28.82
# 65 Peter Polansky              R           180       CAN        29.65
# 66 Philipp Kohlschreiber       R           178       GER        34.53
# 67 Pierre Hugues Herbert       R           188       FRA        27.29
# 68 Rafael Nadal                L           185       ESP        31.95
# 69 Ricardas Berankis           R           175       LTU        28.37
# 70 Richard Gasquet             R           185       FRA        31.98
# 71 Roberto Bautista Agut       R           183       ESP        30.11
# 72 Robin Haase                 R           190       NED        31.03
# 73 Roger Federer               R           185       SUI        36.96
# 74 Rogerio Dutra Silva         R           178       BRA        33.56
# 75 Ryan Harrison               R           183       USA        25.70
# 76 Sandro Ehrat                R           180       SUI        28.39
# 77 Simone Bolelli              R           183       ITA        32.59
# 78 Steve Johnson               R           188       USA        28.18
# 79 Tim Smyczek                 R           175       USA        30.59
# 80 Tobias Kamke                R           180       GER        31.16
# 81 Tommy Robredo               R           180       ESP        34.94
# 82 Vasek Pospisil              R           193       CAN        27.91
# 83 Viktor Troicki              R           193       SRB        31.68
# 84 Yuichi Sugita               R           173       JPN        29.28
#    winner_avg_rank
# 1   42.29
# 2   46.52
# 3  137.00
# 4   66.42
# 5  139.67
# 6  209.12
# 7  191.00
# 8   97.85
# 9  143.50
# 10 108.00
# 11 324.00
# 12  56.73
# 13  74.68
# 14  88.33
# 15  97.94
# 16  25.83
# 17   6.74
# 18  71.44
# 19  65.18
# 20 101.11
# 21 205.36
# 22  94.71
# 23  34.71
# 24  57.54
# 25  25.95
# 26 102.14
# 27 136.00
# 28  63.72
# 29  84.35
# 30  92.00
# ⋮  ⋮
# 55  18.06
# 56  47.33
# 57 237.33
# 58  26.59
# 59  46.23
# 60   4.88
# 61 112.67
# 62  27.07
# 63  47.52
# 64  82.85
# 65 121.60
# 66  40.62
# 67  69.24
# 68   2.62
# 69 105.64
# 70  34.36
# 71  17.87
# 72  55.49
# 73   3.76
# 74  86.25
# 75  59.36
# 76 286.00
# 77 214.20
# 78  42.69
# 79 152.40
# 80 185.00
# 81 386.80
# 82 117.69
# 83  66.38
# 84  54.33

# %%
data_train_summarize <- data_train%>%
    tibble(number_of_players = 84, number_of_right_handed = 75, number_of_left_handed = 9, max_height = max(winner_ht), min_height = min(winner_ht), mean_height = mean(winner_ht),
          number_of_nationalities = 35, max_age = max(winner_avg_age), min_age = min(winner_avg_age), mean_age = mean(winner_avg_age), top_rank = min(winner_avg_rank),
          top_player = "Rafael Nadal", bottom_rank = max(winner_avg_rank), bottom_player = "Tommy Robredo")%>%
    select(number_of_players:bottom_player)%>%
    slice(1)
data_train_summarize

number_of_winner_hand <- data_train%>%
    group_by(winner_hand)%>%
    summarize(n())

nationality_analysis <- data_train%>%
    group_by(winner_ioc)%>%
    summarize(number = n())%>%
    nrow()

ranking <- data_train%>%
    group_by(winner_name)%>%
    summarize(winner_avg_rank)%>%
    arrange(winner_avg_rank)%>%
    slice(1, 84)
# Out:
#   number_of_players number_of_right_handed number_of_left_handed max_height
# 1 84                75                     9                     208
#   min_height mean_height number_of_nationalities max_age min_age mean_age
# 1 170        185.75      35                      39.08   23.02   30.02167
#   top_rank top_player   bottom_rank bottom_player
# 1 2.62     Rafael Nadal 386.8       Tommy Robredo
# `summarise()` ungrouping output (override with `.groups` argument)
#
# `summarise()` ungrouping output (override with `.groups` argument)
#
# `summarise()` ungrouping output (override with `.groups` argument)

# %%
height_data <- data_train %>%
group_by(winner_ht) %>%
summarize(winner_avg_rank_avg = mean(winner_avg_rank))

options(repr.plot.width = 25, repr.plot.height = 10)
data_train_height_barplot <- height_data%>%
    ggplot(aes(x=winner_ht, y=winner_avg_rank_avg, fill = winner_ht))+
        geom_bar(stat = "identity", show.legend = FALSE)+
        labs(x="Height of Winning Player (cm)", y="Mean of Average Rank of Winning Players")+
        ggtitle("Bar Plot of Heights of Tournament-Winning Tennis Players (cm) Against their Average Rank Over Three Years (2017 - 2019)")+
        theme (text = element_text (size = 20))
data_train_height_barplot
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title

# %%
options(repr.plot.width = 25, repr.plot.height = 10)
data_train_height_scatterplot <- data_train%>%
    ggplot(aes(x=winner_ht, y=winner_avg_rank))+
        geom_point()+
        labs(x="Height of Winning Player (cm)", y="Average Rank of Winning Player")+
        ggtitle("Scatterplot of Heights of Tournament-Winning Tennis Players (cm) Against their Average Rank Over Three Years (2017 - 2019)")+
        theme (text = element_text (size = 20))

# %%
options(repr.plot.width = 25, repr.plot.height = 10)
data_train_age_scatterplot <- data_train%>%
    ggplot(aes(x=winner_avg_age, y=winner_avg_rank))+
        geom_point()+
        labs(x="Average Age of Winning Player", y="Average Rank of Winning Player")+
        ggtitle("Scatterplot of Average Ages of Tournament-Winning Tennis Players Against their Average Rank Over Three Years (2017 - 2019)")+
        theme (text = element_text (size = 20))
data_train_age_scatterplot
# Out:
# plot without title

# %%
ioc_data <- data_train %>%
group_by(winner_ioc) %>%
summarize(winner_avg_rank_avg = mean(winner_avg_rank))

options(repr.plot.width = 25, repr.plot.height = 10)
data_train_nationality_barplot <- ioc_data %>%
    ggplot(aes(x=fct_reorder(winner_ioc, winner_avg_rank_avg, .desc = FALSE), y=winner_avg_rank_avg, fill = winner_ioc))+
        geom_bar(stat = "identity", alpha = 0.7)+
        labs(x="Nationality of Winning Player", y="Mean of Average Rank of Winning Player", fill = "Colours")+
        ggtitle("Bar Plot of Nationalities of Tournament-Winning Professional Tennis Players Against their Average Rank Over Three Years (2017 - 2019)")+
        theme (text = element_text (size = 20))
data_train_nationality_barplot
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title

# %%
hand_data <- data_train %>%
group_by(winner_hand) %>%
summarize(winner_avg_rank_avg = mean(winner_avg_rank))

options(repr.plot.width = 25, repr.plot.height = 10)
data_train_hand_barplot <- hand_data %>%
    ggplot(aes(x=winner_hand, y=winner_avg_rank_avg, fill = winner_hand))+
        geom_bar(stat = "identity")+
        labs(x="Handedness of Winning Player (right-handed or left-handed)", y="Mean of Average Rank of Winning Player", fill = "Handedness of Winning Player")+
        ggtitle("Bar Plot of Handedness of Tournament-Winning Professional Tennis Players Against their Average Rank Over Three Years (2017 - 2019)")+
        theme (text = element_text (size = 20))
data_train_hand_barplot
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title
